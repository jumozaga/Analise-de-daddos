# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Dados de Jovens com AIDS no Brasil em 2019.
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DIO - Análise de Dados com Pandas e Python/eixo5_jovensaids_2019.csv')

# %%
#Quantas linhas e colunas tem nesse dataset
df.shape
# Out:
# (27, 9)

# %%
#Exibindo todo o dataset
df.head(27)
# Out:
#     UF                 Nome  Masculino  ...  Total  latitude  longitude
# 0   RO             Rondônia         43  ...     55    -10.83     -63.34
# 1   AC                 Acre          9  ...     11     -8.77     -70.55
# 2   AM             Amazonas        220  ...    284     -3.47     -65.10
# 3   RR              Roraima         32  ...     39      1.99     -61.33
# 4   PA                 Pará        235  ...    347     -3.79     -52.48
# 5   AP                Amapá          8  ...     14      1.41     -51.77
# 6   TO            Tocantins         26  ...     29     -9.46     -48.26
# 7   MA             Maranhão        108  ...    141     -5.42     -45.44
# 8   PI                Piauí         50  ...     59     -6.60     -42.28
# 9   CE                Ceará        146  ...    178     -5.20     -39.53
# 10  RN  Rio Grande do Norte         63  ...     81     -5.81     -36.59
# 11  PB              Paraíba         41  ...     55     -7.28     -36.72
# 12  PE           Pernambuco        170  ...    218     -8.38     -37.86
# 13  AL              Alagoas         50  ...     67     -9.62     -36.82
# 14  SE              Sergipe         39  ...     47    -10.57     -37.45
# 15  BA                Bahia        160  ...    210    -13.29     -41.71
# 16  MG         Minas Gerais        224  ...    262    -18.10     -44.38
# 17  ES       Espírito Santo         53  ...     68    -19.19     -40.34
# 18  RJ       Rio de Janeiro        319  ...    452    -22.25     -42.66
# 19  SP            São Paulo        713  ...    846    -22.19     -48.79
# 20  PR               Paraná        164  ...    211    -24.89     -51.55
# 21  SC       Santa Catarina        146  ...    199    -27.45     -50.95
# 22  RS    Rio Grande do Sul        183  ...    320    -30.17     -53.50
# 23  MS   Mato Grosso do Sul         85  ...    108    -20.51     -54.54
# 24  MT          Mato Grosso        104  ...    125    -12.64     -55.42
# 25  GO                Goiás        140  ...    160    -15.98     -49.86
# 26  DF     Distrito Federal         54  ...     59    -15.83     -47.86
#
# [27 rows x 9 columns]

# %%
#Verificando se há dados em branco/nulos
df.isnull().sum()
# Out:
# UF              0
# Nome            0
# Masculino       0
# Masculino(%)    0
# Feminino        0
# Feminino(%)     0
# Total           0
# latitude        0
# longitude       0
# dtype: int64

# %%
df.describe()
# Out:
#         Masculino  Masculino(%)    Feminino  ...       Total   latitude  longitude
# count   27.000000     27.000000   27.000000  ...   27.000000  27.000000  27.000000
# mean   132.777778      0.781112   39.259259  ...  172.037037 -12.381111 -48.410370
# std    140.922055      0.081541   41.771901  ...  176.154539   8.476122   9.291479
# min      8.000000      0.571429    2.000000  ...   11.000000 -30.170000 -70.550000
# 25%     46.500000      0.754087   10.500000  ...   57.000000 -18.645000 -52.990000
# 50%    104.000000      0.779817   21.000000  ...  125.000000 -10.570000 -48.260000
# 75%    167.000000      0.830894   49.000000  ...  214.500000  -6.205000 -41.025000
# max    713.000000      0.915254  137.000000  ...  846.000000   1.990000 -36.590000
#
# [8 rows x 7 columns]

# %%
rj= df.loc[df["Nome"]=="Rio de Janeiro"]
rj.head()
# Out:
#     UF            Nome  Masculino  ...  Total  latitude  longitude
# 18  RJ  Rio de Janeiro        319  ...    452    -22.25     -42.66
#
# [1 rows x 9 columns]

# %%
sp=df.loc[df["Nome"]=="São Paulo"]
sp.head()
# Out:
#     UF       Nome  Masculino  ...  Total  latitude  longitude
# 19  SP  São Paulo        713  ...    846    -22.19     -48.79
#
# [1 rows x 9 columns]

# %%
#Os 5 primeiros Estados mais contaminados com AIDS no Brasil.
QntGeralAids = df.sort_values("Total", ascending=False).head(5)
QntGeralAids.head(5)
# Out:
#     UF               Nome  Masculino  ...  Total  latitude  longitude
# 19  SP          São Paulo        713  ...    846    -22.19     -48.79
# 18  RJ     Rio de Janeiro        319  ...    452    -22.25     -42.66
# 4   PA               Pará        235  ...    347     -3.79     -52.48
# 22  RS  Rio Grande do Sul        183  ...    320    -30.17     -53.50
# 2   AM           Amazonas        220  ...    284     -3.47     -65.10
#
# [5 rows x 9 columns]

# %%
#Os 3 Estado com mais homens com Aids
df.nlargest(3,"Masculino")
# Out:
#     UF            Nome  Masculino  ...  Total  latitude  longitude
# 19  SP       São Paulo        713  ...    846    -22.19     -48.79
# 18  RJ  Rio de Janeiro        319  ...    452    -22.25     -42.66
# 4   PA            Pará        235  ...    347     -3.79     -52.48
#
# [3 rows x 9 columns]

# %%
#Os 3 Estados com menos homens com aids
df.nsmallest(3,"Masculino")
# Out:
#    UF       Nome  Masculino  ...  Total  latitude  longitude
# 5  AP      Amapá          8  ...     14      1.41     -51.77
# 1  AC       Acre          9  ...     11     -8.77     -70.55
# 6  TO  Tocantins         26  ...     29     -9.46     -48.26
#
# [3 rows x 9 columns]

# %%
#Os 3 Estados com mais mulheres com aids
df.nlargest(3,"Feminino")
# Out:
#     UF               Nome  Masculino  ...  Total  latitude  longitude
# 22  RS  Rio Grande do Sul        183  ...    320    -30.17     -53.50
# 18  RJ     Rio de Janeiro        319  ...    452    -22.25     -42.66
# 19  SP          São Paulo        713  ...    846    -22.19     -48.79
#
# [3 rows x 9 columns]

# %%
#Os 3 Estados com menos mulheres com aids
df.nsmallest(3,"Feminino")
# Out:
#     UF              Nome  Masculino  ...  Total  latitude  longitude
# 1   AC              Acre          9  ...     11     -8.77     -70.55
# 6   TO         Tocantins         26  ...     29     -9.46     -48.26
# 26  DF  Distrito Federal         54  ...     59    -15.83     -47.86
#
# [3 rows x 9 columns]

# %%
#Os cinco Estados com mais homens contaminados em proporção à sua população total.
df.nlargest(5,"Masculino(%)")
# Out:
#     UF              Nome  Masculino  ...  Total  latitude  longitude
# 26  DF  Distrito Federal         54  ...     59    -15.83     -47.86
# 6   TO         Tocantins         26  ...     29     -9.46     -48.26
# 25  GO             Goiás        140  ...    160    -15.98     -49.86
# 16  MG      Minas Gerais        224  ...    262    -18.10     -44.38
# 8   PI             Piauí         50  ...     59     -6.60     -42.28
#
# [5 rows x 9 columns]

# %%
#Os cinco Estados com menos homens contaminados em proporção à sua população total.
df.nsmallest(5,"Masculino(%)")
# Out:
#     UF               Nome  Masculino  ...  Total  latitude  longitude
# 5   AP              Amapá          8  ...     14      1.41     -51.77
# 22  RS  Rio Grande do Sul        183  ...    320    -30.17     -53.50
# 4   PA               Pará        235  ...    347     -3.79     -52.48
# 18  RJ     Rio de Janeiro        319  ...    452    -22.25     -42.66
# 21  SC     Santa Catarina        146  ...    199    -27.45     -50.95
#
# [5 rows x 9 columns]

# %%
#Os cinco Estados com mais mulheres contaminadas em proporção à sua população total.
df.nlargest(5,"Feminino(%)")
# Out:
#     UF               Nome  Masculino  ...  Total  latitude  longitude
# 5   AP              Amapá          8  ...     14      1.41     -51.77
# 22  RS  Rio Grande do Sul        183  ...    320    -30.17     -53.50
# 4   PA               Pará        235  ...    347     -3.79     -52.48
# 18  RJ     Rio de Janeiro        319  ...    452    -22.25     -42.66
# 21  SC     Santa Catarina        146  ...    199    -27.45     -50.95
#
# [5 rows x 9 columns]

# %%
#Os cinco Estados com menos mulheres contaminadas em proporção à sua população total.
minFemP =df.nsmallest(5,"Feminino(%)")

# %%
#Estabelecento métrica
Homens = df.Masculino.sum()
Mulheres = df.Feminino.sum()
total = df.Total.sum()
#Homens e mulheres em porcentagem
PorcentagemHom = (Homens *100)/Total
PorcentagemFem = (Mulheres *100)/Total

# %%
#Visualizando o grupo mais afetado com AIDS
labels = 'Masculino', 'Feminino'
sizes = [ Homens, Mulheres,]
fig1, ax1 = plt.subplots();
explode = (0,0.1); 
ax1.pie(sizes,explode = explode,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90);
ax1.axis('equal');

# %%
#Estados com mais Homens infectados
labels = 'SP', 'RJ', 'PA'
sizes = [713, 319, 235,]
explode = [0.1,0,0]
fig2, ax2 = plt.subplots();
ax2.pie(sizes,labels=labels,explode = explode, autopct='%1.1f%%',shadow=True,startangle=90);
ax2.axis('equal');

# %%
#Estados com mais Mulheres infectadas
labels = 'RS', 'RJ', 'SP'
sizes = [137,133,133]
explode = [0.1,0,0]
fig3, ax3 = plt.subplots();
ax3.pie(sizes,labels=labels,explode = explode, autopct='%1.1f%%',shadow=True,startangle=90);
ax3.axis('equal');

# %%
#Visualizando os TOP Estados Mais Infectados
labels = 'SP','RJ','PA','RS','AM'
sizes = [ 846, 452,347,320,284]
fig4, ax4 = plt.subplots();
explode = (0.1,0,0,0,0); 
ax4.pie(sizes,explode = explode,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90);
ax4.axis('equal');
